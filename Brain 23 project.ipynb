# %%
#Import libraries & Loading and reading the data
import pandas as pd
data =pd.read_csv('Cortex_development_1.csv')
data
# Out:
#         AZUnr  Brainnr  Studynr  Gender   Termdate        Gen  TermdaysLou  \
# 0    498010.0    101.0      1.0     1.0  15-Aug-06  12-Apr-06        155.0
# 1    498010.0    102.0      1.0     1.0  15-Aug-06  26-Apr-06        169.0
# 2    498010.0    103.0      1.0     1.0  15-Aug-06   9-May-06        182.0
# 3    498010.0    104.0      1.0     1.0  15-Aug-06  24-May-06        197.0
# 4    498010.0    105.0      1.0     1.0  15-Aug-06   7-Jun-06        211.0
# ..        ...      ...      ...     ...        ...        ...          ...
# 632       NaN      NaN      NaN     NaN        NaN        NaN          NaN
# 633       NaN      NaN      NaN     NaN        NaN        NaN          NaN
# 634       NaN      NaN      NaN     NaN        NaN        NaN          NaN
# 635       NaN      NaN      NaN     NaN        NaN        NaN          NaN
# 636       NaN      NaN      NaN     NaN        NaN        NaN          NaN
#
# ...

# %%
#for col in data.columns:
    #print(col)

# %%
data2=data[['Brainnr','LSylvian3D1','RSylvian3D','LSuptemp3D1','RSuptemp3D']]
print(data2.shape)
data2.head()
# Out:
# (637, 5)
#    Brainnr LSylvian3D1 RSylvian3D LSuptemp3D1 RSuptemp3D
# 0    101.0           2          2           0          0
# 1    102.0           3          3           0          0
# 2    103.0           3          3           9          9
# 3    104.0           3          3           9          2
# 4    105.0           3          3           3          9

# %%
#Coverting the desirable columns to list
df1=pd.read_csv("video names.csv")
df1 #only video names
df2=pd.read_csv("week names.csv")
df2#only week names
list_video=df1["AVI"].tolist()
list_video# list of video names
list_week=df2["Termweeks"].tolist()
list_week# list of term weeks
list_brainnr=df2["Brainnr"].tolist()
list_brainnr# list of brainnr
# Out:
# [2501,
#  2401,
#  801,
#  2801,
#  3301,
#  701,
#  2601,
#  601,
#  1701,
#  101,
#  201,
#  1101,
#  1801,
#  2301,
#  2201,
#  1401,
#  401,
#  2101,
#  2502,
#  1201,
#  1501,
#  3101,
#  802,
#  2802,
#  1601,
#  3302,
#  301,
#  702,
#  1901,
#  2001,
#  602,
#  1001,
#  2402,
#  501,
#  1702,
#  102,
#  2302,
#  3201,
#  402,
#  2503,
#  1202,
#  3102,
#  2803,
#  202,
#  2202,
#  2602,
#  1602,
#  3303,
#  2102,
#  302,
#  703,
#  1402,
#  1902,
#  901,
#  1102,
#  1502,
#  1802,
#  103,
#  502,
#  603,
#  803,
#  1002,
#  1703,
#  3202,
#  403,
#  2303,
#  1203,
#  2403,
#  3103,
#  2804,
#  203,
#  2203,
#  2603,
#  1603,
#  2504,
#  3304,
#  303,
#  1103,
#  1403,
#  2103,
#  902,
#  1503,
#  1803,
#  503,
#  804,
#  1003,
#  1704,
#  104,
#  2002,
#  3203,
#  2304,
#  404,
#  704,
#  604,
#  3104,
#  1204,
#  2805,
#  2204,
#  2604,
#  3305,
#  1604,
#  2505,
#  204,
#  1903,
#  2104,
#  903,
#  1404,
#  1504,
#  2003,
#  1104,
#  504,
#  105,
#  2305,
#  805,
#  3204,
# ...

# %%
#import pandas as pd
L_week = []
for i in range(len(list_week)):
    for j in range(len(list_video)):
        if str(list_week[i])[0:2]==str(list_video[j])[5:7] and str(list_video[j])[0:3] == str(list_brainnr[i])[0:3] :
            L_week.append(str(list_week[i]))
print(type(L_week))

dfW = pd.DataFrame (L_week, columns = ['Term weeks'])
dfW.head()
# Out:
# <class 'list'>
#   Term weeks
# 0       20.6
# 1       20.6
# 2       20.6
# 3       20.6
# 4       20.6

# %%
#import pandas as pd
L_Brainnnr = []
for i in range(len(list_week)):
    for j in range(len(list_video)):
        if str(list_week[i])[0:2]==str(list_video[j])[5:7] and str(list_video[j])[0:3] == str(list_brainnr[i])[0:3] :
            L_Brainnnr.append(str(list_brainnr[i]))
print(type(L_Brainnnr))

dfB = pd.DataFrame (L_Brainnnr, columns = ['Brainnr number'])
dfB.head()
# Out:
# <class 'list'>
#   Brainnr number
# 0           2501
# 1           2501
# 2           2501
# 3           2501
# 4           2501

# %%
#import pandas as pd
L_Avi = []
for i in range(len(list_week)):
    for j in range(len(list_video)):
        if str(list_week[i])[0:2]==str(list_video[j])[5:7] and str(list_video[j])[0:3] == str(list_brainnr[i])[0:3] :
            L_Avi.append(str(list_video[j]))
print(type(L_Avi))

dfV = pd.DataFrame (L_Avi, columns = ['Video name'])
dfV.head()
# Out:
# <class 'list'>
#             Video name
# 0  2501_20w3d_a1_A.avi
# 1  2501_20w3d_a1_B.avi
# 2  2501_20w3d_a1_C.avi
# 3  2501_20w3d_a2_A.avi
# 4  2501_20w3d_a2_B.avi

# %%
str(list_video[j])[0:4]
# Out:
# '3306'

# %%
#Merging using Outer join
dfWB = dfW.join(dfB, how='outer')
dfWB.head()
# Out:
#   Term weeks Brainnr number
# 0       20.6           2501
# 1       20.6           2501
# 2       20.6           2501
# 3       20.6           2501
# 4       20.6           2501

# %%
df_O = dfWB.join(dfV, how='outer')
df_O.head()
# Out:
#   Term weeks Brainnr number           Video name
# 0       20.6           2501  2501_20w3d_a1_A.avi
# 1       20.6           2501  2501_20w3d_a1_B.avi
# 2       20.6           2501  2501_20w3d_a1_C.avi
# 3       20.6           2501  2501_20w3d_a2_A.avi
# 4       20.6           2501  2501_20w3d_a2_B.avi

# %%
print(df_O.shape)
df_O.head()
# Out:
# (637, 3)
#   Term weeks Brainnr number           Video name
# 0       20.6           2501  2501_20w3d_a1_A.avi
# 1       20.6           2501  2501_20w3d_a1_B.avi
# 2       20.6           2501  2501_20w3d_a1_C.avi
# 3       20.6           2501  2501_20w3d_a2_A.avi
# 4       20.6           2501  2501_20w3d_a2_B.avi

# %%
print(data2.shape)
data2.head()
# Out:
# (637, 5)
#    Brainnr LSylvian3D1 RSylvian3D LSuptemp3D1 RSuptemp3D
# 0    101.0           2          2           0          0
# 1    102.0           3          3           0          0
# 2    103.0           3          3           9          9
# 3    104.0           3          3           9          2
# 4    105.0           3          3           3          9

# %%
#str(list_brainnr[i])[0:3]

# %%
df_main.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 df_main.dtypes
#
# NameError: name 'df_main' is not defined

# %%
data2.dtypes
# Out:
# Brainnr        float64
# LSylvian3D1     object
# RSylvian3D      object
# LSuptemp3D1     object
# RSuptemp3D      object
# dtype: object

# %%
df4=pd.read_csv("Brainnr.f.csv")
# df4.dtypes
print(df4.shape)
df4.head()
df4.dtypes
# Out:
# (218, 6)
# Brainnr number     int64
# LSylvian3D1       object
# RSylvian3D        object
# LSuptemp3D1       object
# RSuptemp3D        object
# HC                object
# dtype: object

# %%
df4_bn = df4.astype(str)
df4_bn.dtypes
df4_bn.head()
# Out:
#   Brainnr number LSylvian3D1 RSylvian3D LSuptemp3D1 RSuptemp3D      HC
# 0            101           2          2           0          0   202.4
# 1            102           3          3           0          0   225.5
# 2            103           3          3           9          9  #NULL!
# 3            104           3          3           9          2   264.1
# 4            105           3          3           3          9     289

# %%
df4_bn.dtypes
# Out:
# Brainnr number    object
# LSylvian3D1       object
# RSylvian3D        object
# LSuptemp3D1       object
# RSuptemp3D        object
# HC                object
# dtype: object

# %%
df_main.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 df_main.head()
#
# NameError: name 'df_main' is not defined

# %%
import numpy as np
df_main
df4
df_main["LSylvian3D1"]=np.nan
df_main["RSylvian3D"]=np.nan
df_main["LSuptemp3D1"]=np.nan
df_main["RSuptemp3D"]=np.nan
#"RSylvian3D","LSuptemp3D1","RSuptemp3D"]=np.nan
for i in range(df4.shape[0]):
    for j in range(df_main.shape[0]):
        if str(df4.iat[i,0])==str(df_main.iat[j,1]):
            df_main.iat[j,3]=df4.iat[i,1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 2>()
#       1 import numpy as np
# ----> 2 df_main
#       3 df4
#       4 df_main["LSylvian3D1"]=np.nan
#
# NameError: name 'df_main' is not defined

# %%
df_main.head(50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 df_main.head(50)
#
# NameError: name 'df_main' is not defined

# %%
dataX =pd.read_csv('Cortex_development.csv')
dataX.shape
# Out:
# (218, 68)

# %%
dataY=dataX[['Brainnr','LSylvian3D1','RSylvian3D','LSuptemp3D1','RSuptemp3D','HC']]
print(dataY.shape)
dataY.head()
# Out:
# (218, 6)
#    Brainnr LSylvian3D1 RSylvian3D LSuptemp3D1 RSuptemp3D      HC
# 0      101           2          2           0          0   202.4
# 1      102           3          3           0          0   225.5
# 2      103           3          3           9          9  #NULL!
# 3      104           3          3           9          2   264.1
# 4      105           3          3           3          9   289.0

# %%
dataO = df_O
print(dataO.shape)
print(dataO.dtypes)
dataO.head()
# Out:
# (637, 3)
# Term weeks        object
# Brainnr number    object
# Video name        object
# dtype: object
#   Term weeks Brainnr number           Video name
# 0       20.6           2501  2501_20w3d_a1_A.avi
# 1       20.6           2501  2501_20w3d_a1_B.avi
# 2       20.6           2501  2501_20w3d_a1_C.avi
# 3       20.6           2501  2501_20w3d_a2_A.avi
# 4       20.6           2501  2501_20w3d_a2_B.avi

# %%
dataM = pd.merge(dataO,df4_bn,on='Brainnr number',how='outer')
print(dataM.shape)
dataM.head()
# Out:
# (779, 8)
#   Term weeks Brainnr number           Video name LSylvian3D1 RSylvian3D  \
# 0       20.6           2501  2501_20w3d_a1_A.avi           2          9
# 1       20.6           2501  2501_20w3d_a1_B.avi           2          9
# 2       20.6           2501  2501_20w3d_a1_C.avi           2          9
# 3       20.6           2501  2501_20w3d_a2_A.avi           2          9
# 4       20.6           2501  2501_20w3d_a2_B.avi           2          9
#
#   LSuptemp3D1 RSuptemp3D     HC
# 0           0          9  181.3
# 1           0          9  181.3
# 2           0          9  181.3
# 3           0          9  181.3
# 4           0          9  181.3

# %%
dataM.loc[dataM['RSuptemp3D'] == '#NULL!']
# Out:
#     Term weeks Brainnr number Video name LSylvian3D1 RSylvian3D LSuptemp3D1  \
# 769        NaN           3205        NaN      #NULL!     #NULL!      #NULL!
#
#     RSuptemp3D     HC
# 769     #NULL!  296.5

# %%
(dataM=='#NULL!').sum()
# Out:
# Term weeks        0
# Brainnr number    0
# Video name        0
# LSylvian3D1       1
# RSylvian3D        1
# LSuptemp3D1       1
# RSuptemp3D        1
# HC                2
# dtype: int64

# %%
dataM['LSylvian3D1'].replace(to_replace = '#NULL!', value = 0, inplace=True)
dataM['RSylvian3D'].replace(to_replace = '#NULL!', value = 0, inplace=True)
dataM['LSuptemp3D1'].replace(to_replace = '#NULL!', value = 0, inplace=True)
dataM['RSuptemp3D'].replace(to_replace = '#NULL!', value = 0, inplace=True)
dataM['HC'].replace(to_replace = '#NULL!', value = 0, inplace=True)

# %%
(dataM=='#NULL!').sum()
# Out:
# Term weeks        0
# Brainnr number    0
# Video name        0
# LSylvian3D1       0
# RSylvian3D        0
# LSuptemp3D1       0
# RSuptemp3D        0
# HC                0
# dtype: int64

# %%
dataM.dtypes
# Out:
# Term weeks        object
# Brainnr number    object
# Video name        object
# LSylvian3D1       object
# RSylvian3D        object
# LSuptemp3D1       object
# RSuptemp3D        object
# HC                object
# dtype: object

# %%
dataM.fillna(0)
# Out:
#     Term weeks Brainnr number           Video name LSylvian3D1 RSylvian3D  \
# 0         20.6           2501  2501_20w3d_a1_A.avi           2          9
# 1         20.6           2501  2501_20w3d_a1_B.avi           2          9
# 2         20.6           2501  2501_20w3d_a1_C.avi           2          9
# 3         20.6           2501  2501_20w3d_a2_A.avi           2          9
# 4         20.6           2501  2501_20w3d_a2_B.avi           2          9
# ..         ...            ...                  ...         ...        ...
# 774          0           3304                    0           4          9
# 775          0           3305                    0           4          4
# 776          0           3307                    0           5          9
# 777          0           3308                    0           5          9
# 778          0           3309                    0           5          9
#
#     LSuptemp3D1 RSuptemp3D     HC
# 0             0          9  181.3
# ...

# %%
dataM.describe()
# Out:
#        Term weeks Brainnr number           Video name LSylvian3D1 RSylvian3D  \
# count         637            779                  637         779        779
# unique         64            218                  637           8          7
# top          31.1           2309  2501_20w3d_a1_A.avi           5          9
# freq           36             12                    1         225        300
#
#        LSuptemp3D1 RSuptemp3D     HC
# count          779        779    779
# unique           8          8    202
# top              9          9  200.8
# freq           437        470     18

# %%
dataM["LSylvian3D1"] = dataM["LSylvian3D1"].astype(int)
dataM["RSylvian3D"] = dataM["RSylvian3D"].astype(int)
dataM["LSuptemp3D1"] = dataM["LSuptemp3D1"].astype(int)
dataM["RSuptemp3D"] = dataM["RSuptemp3D"].astype(int)
dataM["HC"] = dataM["HC"].astype(float)
print(dataM.dtypes)
# Out:
# Term weeks         object
# Brainnr number     object
# Video name         object
# LSylvian3D1         int64
# RSylvian3D          int64
# LSuptemp3D1         int64
# RSuptemp3D          int64
# HC                float64
# dtype: object

# %%
dataM['LSylvian3D1'].mean()
# Out:
# 5.191270860077021

# %%
dataM['RSylvian3D'].mean()
# Out:
# 5.741976893453145

# %%
dataM['LSuptemp3D1'].mean()
# Out:
# 6.2798459563543005

# %%
dataM['RSuptemp3D'].mean()
# Out:
# 6.694480102695763

# %%
dataM.describe()
# Out:
#        LSylvian3D1  RSylvian3D  LSuptemp3D1  RSuptemp3D          HC
# count   779.000000  779.000000   779.000000  779.000000  779.000000
# mean      5.191271    5.741977     6.279846    6.694480  272.141335
# std       2.639063    2.728300     3.403271    3.088099   48.205737
# min       0.000000    0.000000     0.000000    0.000000    0.000000
# 25%       3.000000    3.000000     5.000000    5.000000  233.000000
# 50%       5.000000    5.000000     9.000000    9.000000  279.400000
# 75%       9.000000    9.000000     9.000000    9.000000  313.900000
# max       9.000000    9.000000     9.000000    9.000000  351.800000

# %%
dataM.head(779)
# Out:
#     Term weeks Brainnr number           Video name  LSylvian3D1  RSylvian3D  \
# 0         20.6           2501  2501_20w3d_a1_A.avi            2           9
# 1         20.6           2501  2501_20w3d_a1_B.avi            2           9
# 2         20.6           2501  2501_20w3d_a1_C.avi            2           9
# 3         20.6           2501  2501_20w3d_a2_A.avi            2           9
# 4         20.6           2501  2501_20w3d_a2_B.avi            2           9
# ..         ...            ...                  ...          ...         ...
# 774        NaN           3304                  NaN            4           9
# 775        NaN           3305                  NaN            4           4
# 776        NaN           3307                  NaN            5           9
# 777        NaN           3308                  NaN            5           9
# 778        NaN           3309                  NaN            5           9
#
#      LSuptemp3D1  RSuptemp3D     HC
# ...

# %%
dataM.loc[dataM['Brainnr number'] == '2501']
# Out:
#    Term weeks Brainnr number           Video name  LSylvian3D1  RSylvian3D  \
# 0        20.6           2501  2501_20w3d_a1_A.avi            2           9
# 1        20.6           2501  2501_20w3d_a1_B.avi            2           9
# 2        20.6           2501  2501_20w3d_a1_C.avi            2           9
# 3        20.6           2501  2501_20w3d_a2_A.avi            2           9
# 4        20.6           2501  2501_20w3d_a2_B.avi            2           9
# 5        20.6           2501  2501_20w3d_a2_C.avi            2           9
# 6        20.6           2501   2501_20w3d_s_B.avi            2           9
# 7        20.6           2501   2501_20w3d_s_C.avi            2           9
# 8        20.6           2501  2501_20w4d_a1_A.avi            2           9
# 9        20.6           2501  2501_20w4d_a1_B.avi            2           9
# 10       20.6           2501  2501_20w4d_a1_C.avi            2           9
#
#     LSuptemp3D1  RSuptemp3D     HC
# ...

# %%
dataM["HC"] = dataM["HC"].astype(int)

# %%
dataM.dtypes
# Out:
# Term weeks        object
# Brainnr number    object
# Video name        object
# LSylvian3D1        int64
# RSylvian3D         int64
# LSuptemp3D1        int64
# RSuptemp3D         int64
# HC                 int64
# dtype: object

# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import datasets

# %%
# !pip install imblearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
import numpy as np

# %%
pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn import metrics
from sklearn import preprocessing
from sklearn.metrics import plot_roc_curve
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBClassifier

import numpy as np
from imblearn import under_sampling, over_sampling
from imblearn.over_sampling import SMOTENC

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_selection import chi2, SelectKBest
from sklearn.feature_selection import mutual_info_classif
from sklearn.metrics import plot_roc_curve, roc_auc_score, accuracy_score, confusion_matrix, classification_report, fbeta_score
from sklearn import preprocessing

# %%
# Defining dependent and independent varaibles
y = dataM["HC"]
X = dataM[['LSylvian3D1', 'RSylvian3D', 'LSuptemp3D1','RSuptemp3D']]
#Training data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=10)

# %% [markdown]
# # Logistic Regression

# %%
logReg = LogisticRegression()
logReg.fit(X_test, y_test)
log_score = logReg.score(X_test, y_test)
print("The accuracy of the Logistic model is", log_score*100)
print('')
log_pred = logReg.predict(X_test)
print(classification_report(y_test, log_pred))
# Out:
# The accuracy of the Logistic model is 29.743589743589745
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#          176       0.00      0.00      0.00         1
#          181       0.40      1.00      0.57         2
#          184       0.00      0.00      0.00         1
#          196       0.00      0.00      0.00         2
#          198       0.00      0.00      0.00         3
#          200       0.00      0.00      0.00        11
#          202       0.00      0.00      0.00         1
#          205       0.00      0.00      0.00         3
#          207       1.00      1.00      1.00         2
#          208       0.00      0.00      0.00         2
#          210       0.00      0.00      0.00         4
#          218       0.00      0.00      0.00         1
#          228       0.00      0.00      0.00         2
#          229       0.50      1.00      0.67         5
# ...

# %% [markdown]
# # Decision Tree classifier

# %%
DCC = DecisionTreeClassifier()
DCC.fit(X_test, y_test)
dt_score = DCC.score(X_test, y_test)
print("The accuracy of Decision tree classifier model is", dt_score)
print('')
Dectree_pred = DCC.predict(X_test)
print(classification_report(y_test, Dectree_pred))
# Out:
# The accuracy of Decision tree classifier model is 0.5538461538461539
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#          176       0.00      0.00      0.00         1
#          181       0.40      1.00      0.57         2
#          184       0.50      1.00      0.67         1
#          196       0.00      0.00      0.00         2
#          198       0.22      0.67      0.33         3
#          200       0.85      1.00      0.92        11
#          202       1.00      1.00      1.00         1
#          205       0.00      0.00      0.00         3
#          207       1.00      1.00      1.00         2
#          208       0.00      0.00      0.00         2
#          210       1.00      0.50      0.67         4
#          218       1.00      1.00      1.00         1
#          228       0.40      1.00      0.57         2
#          229       1.00      1.00      1.00         5
# ...

# %% [markdown]
# # Random Forest Classifier

# %%
RFC = RandomForestClassifier(n_estimators = 2)
RFC.fit(X_test, y_test)
rf_score = RFC.score(X_test, y_test)
print("The accuracy of Random forest model is", rf_score)
print('')
randfor_pred = RFC.predict(X_test)
print(classification_report(y_test, randfor_pred))
# Out:
# The accuracy of Random forest model is 0.5025641025641026
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#          176       0.00      0.00      0.00         1
#          181       0.40      1.00      0.57         2
#          184       0.00      0.00      0.00         1
#          196       0.50      0.50      0.50         2
#          198       0.25      0.33      0.29         3
#          200       0.89      0.73      0.80        11
#          202       1.00      1.00      1.00         1
#          205       0.22      0.67      0.33         3
#          207       1.00      1.00      1.00         2
#          208       0.00      0.00      0.00         2
#          210       1.00      0.50      0.67         4
#          218       1.00      1.00      1.00         1
#          228       0.00      0.00      0.00         2
#          229       0.62      1.00      0.77         5
# ...

# %% [markdown]
# # Gradient Boosting Classifier

# %%
GBC = GradientBoostingClassifier(learning_rate=0.1)
GBC.fit(X_test, y_test)
Graboo_pred = GBC.predict(X_test)
gb_score = GBC.score(X_test, y_test)
print("The accuracy of Gradient boosting model is", gb_score)
print('')
print(classification_report(y_test, Graboo_pred))
# Out:
# The accuracy of Gradient boosting model is 0.5538461538461539
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#          176       0.00      0.00      0.00         1
#          181       0.40      1.00      0.57         2
#          184       0.50      1.00      0.67         1
#          196       0.00      0.00      0.00         2
#          198       0.22      0.67      0.33         3
#          200       0.85      1.00      0.92        11
#          202       1.00      1.00      1.00         1
#          205       0.00      0.00      0.00         3
#          207       1.00      1.00      1.00         2
#          208       0.00      0.00      0.00         2
#          210       1.00      0.50      0.67         4
#          218       1.00      1.00      1.00         1
#          228       0.40      1.00      0.57         2
#          229       1.00      1.00      1.00         5
# ...

# %% [markdown]
# # Gaussian Naive Bayes classifier

# %%
GNB = GaussianNB()
GNB.fit(X_test, y_test)
nb_score = GNB.score(X_test, y_test)
print("The accuracy of Naive Bayes model is", nb_score)
print('')
Naibay_pred = GNB.predict(X_test)
print(classification_report(y_test, Naibay_pred))
# Out:
# The accuracy of Naive Bayes model is 0.4358974358974359
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#          176       0.00      0.00      0.00         1
#          181       0.40      1.00      0.57         2
#          184       0.50      1.00      0.67         1
#          196       0.00      0.00      0.00         2
#          198       0.25      0.33      0.29         3
#          200       0.00      0.00      0.00        11
#          202       1.00      1.00      1.00         1
#          205       0.17      0.33      0.22         3
#          207       1.00      1.00      1.00         2
#          208       0.00      0.00      0.00         2
#          210       0.00      0.00      0.00         4
#          218       1.00      1.00      1.00         1
#          228       0.40      1.00      0.57         2
#          229       1.00      1.00      1.00         5
# ...

# %%
df_O.head()
# Out:
#   Term weeks Brainnr number           Video name
# 0       20.6           2501  2501_20w3d_a1_A.avi
# 1       20.6           2501  2501_20w3d_a1_B.avi
# 2       20.6           2501  2501_20w3d_a1_C.avi
# 3       20.6           2501  2501_20w3d_a2_A.avi
# 4       20.6           2501  2501_20w3d_a2_B.avi

# %%
df_O.shape
# Out:
# (637, 3)

# %%
df4=pd.read_csv("Brainnr.f.csv")
# df4.dtypes
print(df4.shape)
df4.head()
# Out:
# (218, 6)
#    Brainnr number LSylvian3D1 RSylvian3D LSuptemp3D1 RSuptemp3D      HC
# 0             101           2          2           0          0   202.4
# 1             102           3          3           0          0   225.5
# 2             103           3          3           9          9  #NULL!
# 3             104           3          3           9          2   264.1
# 4             105           3          3           3          9     289

# %%
dataM.head(779)
# Out:
#     Term weeks Brainnr number           Video name  LSylvian3D1  RSylvian3D  \
# 0         20.6           2501  2501_20w3d_a1_A.avi            2           9
# 1         20.6           2501  2501_20w3d_a1_B.avi            2           9
# 2         20.6           2501  2501_20w3d_a1_C.avi            2           9
# 3         20.6           2501  2501_20w3d_a2_A.avi            2           9
# 4         20.6           2501  2501_20w3d_a2_B.avi            2           9
# ..         ...            ...                  ...          ...         ...
# 774        NaN           3304                  NaN            4           9
# 775        NaN           3305                  NaN            4           4
# 776        NaN           3307                  NaN            5           9
# 777        NaN           3308                  NaN            5           9
# 778        NaN           3309                  NaN            5           9
#
#      LSuptemp3D1  RSuptemp3D   HC
# ...

# %%
dataM.shape
# Out:
# (779, 8)
